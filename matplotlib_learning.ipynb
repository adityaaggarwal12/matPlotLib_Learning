# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# basic graph

# %%
x=[1,4,6]
y=[1,2,7]
plt.plot(x,y)
plt.title("First Graphh",fontdict={'fontname':"Comic Sans MS"})
plt.xlabel("xxxxxxx")
plt.ylabel("yyyyyyy")

plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
