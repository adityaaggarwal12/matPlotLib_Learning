# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# linr graph
gas = pd.read_csv('gas_prices.csv')

plt.title('Gas prices (USD)')

plt.plot(gas.Year,gas.USA ,'b*-', label='USA')
plt.plot(gas.Year,gas.Canada ,'r.-', label='Canada')
plt.plot(gas.Year,gas['South Korea'] ,'gp-', label='South Korea')
plt.plot(gas.Year,gas.Australia ,'y+-', label='South Korea')



plt.xticks(gas.Year[::3])

plt.xlabel('Year')
plt.ylabel('U S D')


plt.legend()
plt.savefig('gas_comparison.png',dpi=300)



plt.show()

# %%
gas = pd.read_csv('gas_prices.csv')

plt.title('Gas prices (USD)')

for country in gas:
    if country != 'Year':
        plt.plot(gas.Year,gas[country],label=country,marker='.')

plt.xticks(gas.Year[::3])

plt.xlabel('Year')
plt.ylabel('U S D')


plt.legend()

plt.savefig('all_countries_comparison.png',dpi=300)


plt.show()
